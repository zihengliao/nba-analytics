# %%
from nba_api.stats.static import players
from nba_api.stats.endpoints import PlayerGameLog
import pandas as pd

# %%
lebron = players.find_players_by_full_name("LeBron James")[0]
lebron_id = lebron["id"]

# %%
gamelog = PlayerGameLog(
    player_id=lebron_id,
    season="2003-04",
    season_type_all_star="Regular Season"
)

df = gamelog.get_data_frames()[0]

# %%
df["GAME_DATE"] = pd.to_datetime(df["GAME_DATE"])

# %%
df_sorted = df.sort_values("GAME_DATE")

# %%
first_10_games = df_sorted.head(10)

# %%
first_10_games
# Out:
#    SEASON_ID  Player_ID     Game_ID  GAME_DATE      MATCHUP WL  MIN  FGM  FGA  \
# 78     22003       2544  0020300014 2003-10-29    CLE @ SAC  L   42   12   20
# 77     22003       2544  0020300018 2003-10-30    CLE @ PHX  L   41    8   17
# 76     22003       2544  0020300038 2003-11-01    CLE @ POR  L   39    3   12
# 75     22003       2544  0020300057 2003-11-05  CLE vs. DEN  L   41    3   11
# 74     22003       2544  0020300068 2003-11-07    CLE @ IND  L   44    8   18
# 73     22003       2544  0020300078 2003-11-08  CLE vs. WAS  W   45    8   19
# 72     22003       2544  0020300090 2003-11-10  CLE vs. NYK  W   34    7   12
# 71     22003       2544  0020300106 2003-11-12    CLE @ MIA  L   42    6   15
# 70     22003       2544  0020300115 2003-11-14    CLE @ BOS  L   35    3   12
# 69     22003       2544  0020300130 2003-11-15  CLE vs. PHI  W   47   10   19
#
#     FG_PCT  ...  DREB  REB  AST  STL  BLK  TOV  PF  PTS  PLUS_MINUS  \
# 78   0.600  ...     4    6    9    4    0    2   3   25          -9
# 77   0.471  ...    10   12    8    1    0    7   1   21          -3
# 76   0.250  ...     4    4    6    2    0    2   3    8         -21
# 75   0.273  ...     9   11    7    2    3    2   1    7          -3
# 74   0.444  ...     5    5    3    0    0    7   2   23          -7
# 73   0.421  ...     3    8    9    1    1    2   1   17          14
# 72   0.583  ...     4    5    4    1    1    2   0   17          20
# 71   0.400  ...     2    3    7    2    1    4   3   18          -4
# 70   0.250  ...     4    5    3    0    0    4   3   10          -1
# 69   0.526  ...     5    5    8    1    2    5   2   22           8
#
#     VIDEO_AVAILABLE
# 78                0
# 77                0
# 76                0
# 75                0
# 74                0
# 73                0
# 72                0
# 71                0
# 70                0
# 69                0
#
# [10 rows x 27 columns]

# %%
df
# Out:
#    SEASON_ID  Player_ID     Game_ID     GAME_DATE      MATCHUP WL  MIN  FGM  \
# 0      22003       2544  0020301179  Apr 14, 2004    CLE @ NYK  W   35    8
# 1      22003       2544  0020301162  Apr 12, 2004  CLE vs. MIL  W   45    9
# 2      22003       2544  0020301151  Apr 10, 2004  CLE vs. MIA  W   32    4
# 3      22003       2544  0020301137  Apr 09, 2004    CLE @ MIA  L   42    6
# 4      22003       2544  0020301128  Apr 07, 2004    CLE @ MEM  L   36    4
# ..       ...        ...         ...           ...          ... ..  ...  ...
# 74     22003       2544  0020300068  Nov 07, 2003    CLE @ IND  L   44    8
# 75     22003       2544  0020300057  Nov 05, 2003  CLE vs. DEN  L   41    3
# 76     22003       2544  0020300038  Nov 01, 2003    CLE @ POR  L   39    3
# 77     22003       2544  0020300018  Oct 30, 2003    CLE @ PHX  L   41    8
# 78     22003       2544  0020300014  Oct 29, 2003    CLE @ SAC  L   42   12
#
#     FGA  FG_PCT  ...  DREB  REB  AST  STL  BLK  TOV  PF  PTS  PLUS_MINUS  \
# 0    17   0.471  ...     1    1    5    3    0    5   1   17          -6
# 1    20   0.450  ...     6    7    9    2    0    1   1   27          11
# 2    11   0.364  ...     2    3   11    0    0    2   3   10          14
# 3    14   0.429  ...     6    7    8    1    0    8   2   24         -16
# 4    11   0.364  ...     3    3    5    3    0    2   4   14         -11
# ..  ...     ...  ...   ...  ...  ...  ...  ...  ...  ..  ...         ...
# 74   18   0.444  ...     5    5    3    0    0    7   2   23          -7
# 75   11   0.273  ...     9   11    7    2    3    2   1    7          -3
# 76   12   0.250  ...     4    4    6    2    0    2   3    8         -21
# 77   17   0.471  ...    10   12    8    1    0    7   1   21          -3
# 78   20   0.600  ...     4    6    9    4    0    2   3   25          -9
#
#     VIDEO_AVAILABLE
# 0                 0
# 1                 0
# 2                 0
# 3                 0
# 4                 0
# ..              ...
# 74                0
# 75                0
# 76                0
# 77                0
# 78                0
#
# [79 rows x 27 columns]
